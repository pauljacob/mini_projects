# %% [markdown]
# </font> <font>Table of Contents</font> <font size="2">[3.0 Data Wrangling](#[3.0_Data_Wrangling])</font> <font size="2">[4.0 Feature Engineering](#[4.0_Feature_Engineering])</font> <font size="2">[5.0 Exploratory Data Analysis](#[5.0_Exploratory_Data_Analysis])</font>  <font size="2">[6.0 Modeling](#[6.0_Modeling])</font> <font size="2">[7.0 Results](#[7.0_Results])</font>

# %% [markdown]
# # Income of Adults: Data Story Telling<a id='Income_of_Adults_Data_Story_Telling'></a>

# %% [markdown]
# ## 1.0 Link the Python Site Packages Folder

# %%
import sys
source_directory = "/Users/pauljacob/Library/Python/3.8/lib/python/site-packages"
sys.path.append(source_directory)

# %% [markdown]
# ## 2.0 Installs, Imports, and Initializations<a id='2.0_Imports_and_Initializations'></a>

# %% [markdown]
# ### 2.1 Install Packages<a id='2.1_Install_Packages'></a>

# %%
# %%capture
# !pip3 install adjustText

# %% [markdown]
# ### 2.2 Import Packages and Scripts<a id='2.2_Import_Packages_and_Scripts'></a>

# %%
#Notebook Intialization
from IPython.core.display import display, HTML
import Income_of_Adults_Data_Story_Telling as ioa

#Data Wrangling
import pandas as pd
import numpy as np
import os
from Income_of_Adults_Data_Story_Telling import p, rcr

#Exploratory Data Analysis
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
from adjustText import adjust_text
from scipy.interpolate import interp1d
from matplotlib.ticker import FuncFormatter

#Modeling
from scipy import stats
# Out:
# /var/folders/77/y4hv4_s9751293nzv4yrfrtm0000gn/T/ipykernel_71091/2578067041.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %% [markdown]
# ### 2.3 Initialize the Notebook<a id='2.3_Initialize_Notebook'></a>

# %%
filename_version='1.3'
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
pd.options.display.max_info_columns = 999
pd.set_option('display.max_colwidth', None)
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# <font size="5"><a id='[3.0_Data_Wrangling]'></a> </font> </font> <font>Table of Contents</font> <font size="2">[3.0 Data Wrangling](#[3.0_Data_Wrangling])</font> <font size="2">[4.0 Feature Engineering](#[4.0_Feature_Engineering])</font> <font size="2">[5.0 Exploratory Data Analysis](#[5.0_Exploratory_Data_Analysis])</font>  <font size="2">[6.0 Modeling](#[6.0_Modeling])</font> <font size="2">[7.0 Results](#[7.0_Results])</font>

# %% [markdown]
# <font size="5"><a id='[3.0_Data_Wrangling]'>**3.0 Data Wrangling**</a> </font>

# %% [markdown]
# ### 3.1 Load the Data<a id='3.0_Load_The_Data'></a>

# %%
df = rcr('adult.csv')
#p(df)

# %% [markdown]
# ### 3.2 Clean the Data<a id='3.2_Clean_the_Data'></a>

# %%
df=ioa.clean_the_DataFrame(df)
#p(df)

# %% [markdown]
# <font size="5"><a id='[4.0_Feature_Engineering]'> </a> </font> </font> <font>Table of Contents</font> <font size="2">[3.0 Data Wrangling](#[3.0_Data_Wrangling])</font> <font size="2">[4.0 Feature Engineering](#[4.0_Feature_Engineering])</font> <font size="2">[5.0 Exploratory Data Analysis](#[5.0_Exploratory_Data_Analysis])</font>  <font size="2">[6.0 Modeling](#[6.0_Modeling])</font> <font size="2">[7.0 Results](#[7.0_Results])</font>

# %% [markdown]
# <font size="5"><a id='[4.0_Feature_Engineering]'>**4.0 Feature Engineering**</a> </font>

# %% [markdown]
# ### 4.1 Extract and Add Features <a id='4.1_Extract_and_Add_Features '></a>

# %%
df=ioa.extract_and_add_features(df)
p(df)
# Out:
# (48842, 22)
#        Age    Work class  Final weight             Education  \
# 0       25       Private        226802            11th grade
# 1       38       Private         89814  High school graduate
# 2       28     Local-gov        336951   Associates academic
# 3       44       Private        160323          Some college
# 4       18       Unknown        103497          Some college
# 48837   27       Private        257302   Associates academic
# 48838   40       Private        154374  High school graduate
# 48839   58       Private        151910  High school graduate
# 48840   22       Private        201490  High school graduate
# 48841   52  Self-emp-inc        287927  High school graduate
#
#        Educational number           Marital status  \
# 0                       7            Never married
# 1                       9  Married civilian spouse
# 2                      12  Married civilian spouse
# 3                      10  Married civilian spouse
# ...

# %% [markdown]
# <font size="5"><a id='[5.0_Exploratory_Data_Analysis]'> </a> </font> </font> <font>Table of Contents</font> <font size="2">[3.0 Data Wrangling](#[3.0_Data_Wrangling])</font> <font size="2">[4.0 Feature Engineering](#[4.0_Feature_Engineering])</font> <font size="2">[5.0 Exploratory Data Analysis](#[5.0_Exploratory_Data_Analysis])</font>  <font size="2">[6.0 Modeling](#[6.0_Modeling])</font> <font size="2">[7.0 Results](#[7.0_Results])</font>

# %% [markdown]
# <font size="5"><a id='[5.0_Exploratory_Data_Analysis]'>**5.0 Exploratory Data Analysis**</a> </font>

# %% [markdown]
# ### 5.1 Data Visualization<a id='5.1_Data_Visualization'></a>

# %%
#Initialize the Variables
kind_string='pie'
target_column_name_string='Income'
figure_filename='../reports/figures/figure_'+target_column_name_string.replace(' ', '_').lower()+'_'+kind_string+'_plot'+'.png'

title_string=target_column_name_string.title()+' Distribution'

color_list=['#bae4bc', '#43a2ca']
figure_size=(15,10)
startangle=90

#Create the Plot
figure, axes=plt.subplots(nrows=1, ncols=1, figsize=figure_size)
df.groupby(['Income']).size().plot(kind=kind_string, y=target_column_name_string, figsize=figure_size, startangle=startangle, autopct='%1.0f%%', colors=color_list, textprops={'fontsize': 16})

plt.title(label=title_string)
plt.xlabel(xlabel='')
plt.ylabel(ylabel='')

plt.legend(['>50K', '≤50K'])

plt.savefig(figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Initialize the Variables
target_column_name_string='Income'

title_string=target_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

figure_size=(8,6)

#DataFrame Calculation
df_income_frequency=df.loc[:, target_column_name_string].value_counts().to_frame().reset_index().rename(columns={'index':target_column_name_string, target_column_name_string:'Frequency'})

#Create the Plot
figure, axes=plt.subplots(nrows=1, ncols=1, figsize=figure_size)

plt.bar(df_income_frequency.loc[:, target_column_name_string], df_income_frequency.loc[:, 'Frequency'])

plt.xlabel(target_column_name_string)
plt.ylabel('Frequency')
plt.title(label=title_string)

plt.tight_layout()

plt.savefig(fname=figure_filename, dpi=100)
plt.show()

# %%
#Initialize the Variables
feature_column_name_string='Age'

title_string=feature_column_name_string.title()+' Distribution 2'

figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

figure_size=(8,6)

#DataFrame Calculation
df_age_frequency=df.loc[:, 'Age'].value_counts().to_frame().sort_index().reset_index().rename(columns={'index':'Age', 'Age':'Frequency'})

#Create the Plot
figure, axes=plt.subplots(nrows=1, ncols=1, figsize=figure_size)

plt.stem(df_age_frequency.loc[:, 'Age'], df_age_frequency.loc[:, 'Frequency'])

plt.xlabel(feature_column_name_string)
plt.ylabel('Frequency')
plt.title('Age Distribution')


plt.tight_layout()

plt.savefig(fname=figure_filename, dpi=100)
plt.show()

# %%
#Intialize the Variables
kind_string='bar'
feature_column_name_string='Gender'
title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

color_list=['#8c6bb1', '#41ab5d']

figure_size=(12, 10)

font_scale_float=1.5


#DataFrame Calculation
df_gender_income=df.groupby(['Gender', 'Income']).size().unstack().reset_index()
df_gender_income.loc[:, 'total']=df_gender_income.loc[:, '≤50K']+df_gender_income.loc[:, '>50K']
df_gender_income.loc[:, '>50K_rate']=df_gender_income.loc[:, '>50K']/df_gender_income.loc[:, 'total']
df_gender_income=df_gender_income.sort_values('>50K_rate', ascending=False)
df_gender_income=df_gender_income.drop(columns=['total', '>50K_rate'])

df_total=df_gender_income["≤50K"]+df_gender_income[">50K"]
df_rel=df_gender_income[df_gender_income.columns[1:]].div(df_total, 0)*100


#Create the Plot
sns.set(font_scale=font_scale_float)

df_gender_income.plot(x=feature_column_name_string, kind=kind_string, stacked=True, title=title_string, mark_right=True, color=color_list, figsize=figure_size)

for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(df_gender_income.iloc[:, 1:].cumsum(1)[n], df_gender_income[n], df_rel[n])):
        plt.text(i, cs-ab/2, str(np.round(pc, 1))+'%', va='center', ha='center', rotation=0, fontsize=14)
        
plt.ylabel('Frequency')

plt.savefig(figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Race'

title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

color_list=['#2c9bb2', '#11eb5e']

figure_size=(12, 10)

plot_kind='bar'
font_scale_float=1.5


#DataFrame Calculation
df_race_income = df.groupby(['Race', 'Income']).size().unstack().reset_index()
df_race_income.loc[:, 'total'] = df_race_income.loc[:, '≤50K'] + df_race_income.loc[:, '>50K']
df_race_income.loc[:, '>50K_rate'] = df_race_income.loc[:, '>50K'] / df_race_income.loc[:, 'total']
df_race_income = df_race_income.sort_values('>50K_rate', ascending=False)
df_race_income = df_race_income.drop(columns=['total', '>50K_rate'])

df_total = df_race_income["≤50K"] + df_race_income[">50K"]
df_rel = df_race_income[df_race_income.columns[1:]].div(df_total, 0) * 100


#Create the Plot
sns.set(font_scale=font_scale_float)

df_race_income.plot(x=feature_column_name_string, kind=plot_kind, stacked=True, title=title_string, mark_right=True, color=color_list, figsize=figure_size)

text = [plt.text(i, cs-ab / 2, str(np.round(pc, 1))+'%', va='center', ha='center', rotation=0, fontsize=14) for n in df_rel for i, (cs, ab, pc) in enumerate(zip(df_race_income.iloc[:, 1:].cumsum(1)[n], df_race_income[n], df_rel[n]))]

        
plt.ylabel('Frequency')

plt.tight_layout()

plt.savefig(fname=figure_filename, dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Occupation'

title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

plot_kind='bar'

color_list=['#7fcdbb', '#fc9272']

figure_size=(12, 10)

font_scale_float=1.5


#DataFrame Calculation
df_occupation_income = df.groupby(['Occupation', 'Income']).size().unstack().reset_index()
df_occupation_income.loc[:, 'total']=df_occupation_income.loc[:, '≤50K']+df_occupation_income.loc[:, '>50K']
df_occupation_income.loc[:, '>50K_rate']=df_occupation_income.loc[:, '>50K']/df_occupation_income.loc[:, 'total']
df_occupation_income=df_occupation_income.sort_values(['>50K_rate', 'total'], ascending=False)
df_occupation_income=df_occupation_income.drop(columns=['total', '>50K_rate'])

df_total = df_occupation_income["≤50K"] + df_occupation_income[">50K"]
df_rel = df_occupation_income[df_occupation_income.columns[1:]].div(df_total, 0) * 100


#Create the Plot
sns.set(font_scale=font_scale_float)

df_occupation_income.plot(x=feature_column_name_string, kind=plot_kind, stacked=True, title=title_string, mark_right = True, color=color_list, figsize=figure_size)

for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(df_occupation_income.iloc[:, 1:].cumsum(1)[n], df_occupation_income[n], df_rel[n])):
        plt.text(i, cs-ab/2, str(np.round(pc, 1))+'%', va='center', ha='center', rotation=0, fontsize=14)
        
plt.ylabel('Frequency')

plt.tight_layout()

plt.savefig(fname=figure_filename, dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Work class'

plot_kid='bar'

title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

color_list=['#ffeda0', '#a6bddb']

font_scale_float=1.5
sns.set(font_scale=font_scale_float)

figure_size=(12, 10)


#DataFrame Calculation
df_workclass_income = df.groupby(['Work class', 'Income']).size().unstack().reset_index().fillna(0)
df_workclass_income.loc[:, 'total']=df_workclass_income.loc[:, '≤50K']+df_workclass_income.loc[:, '>50K']
df_workclass_income.loc[:, '>50K_rate']=df_workclass_income.loc[:, '>50K']/df_workclass_income.loc[:, 'total']
df_workclass_income=df_workclass_income.sort_values(['>50K_rate', 'total'], ascending=False)
df_workclass_income=df_workclass_income.drop(columns=['total', '>50K_rate'])

df_total=df_workclass_income["≤50K"]+df_workclass_income[">50K"]
df_rel=df_workclass_income[df_workclass_income.columns[1:]].div(df_total, 0)*100


#Create the Plot
df_workclass_income.plot(x=feature_column_name_string, kind=plot_kid, stacked=True, title=title_string, mark_right=True, color=color_list, figsize=figure_size)

for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(df_workclass_income.iloc[:, 1:].cumsum(1)[n], df_workclass_income[n], df_rel[n])):
        plt.text(i, cs - ab / 2, str(np.round(pc, 1)) + '%', va = 'center', ha='center', rotation=0, fontsize=14)
        
plt.ylabel('Frequency')

plt.tight_layout()

plt.savefig(fname=figure_filename, dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Marital status'

font_scale_float=1.5

plot_kind='bar'

color_list=['#fee8c8', '#addd8e']

figure_size=(12, 10)

title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'


#DataFrame Calculation
df_marital_status_income = df.groupby(['Marital status', 'Income']).size().unstack().reset_index()
df_marital_status_income.loc[:, 'total']=df_marital_status_income.loc[:, '≤50K']+df_marital_status_income.loc[:, '>50K']
df_marital_status_income.loc[:, '>50K_rate']=df_marital_status_income.loc[:, '>50K']/df_marital_status_income.loc[:, 'total']
df_marital_status_income = df_marital_status_income.sort_values(['>50K_rate', 'total'], ascending=False)
df_marital_status_income = df_marital_status_income.drop(columns=['total', '>50K_rate'])

df_total=df_marital_status_income["≤50K"] + df_marital_status_income[">50K"]
df_rel=df_marital_status_income[df_marital_status_income.columns[1:]].div(df_total, 0) * 100


#Create the Plot
sns.set(font_scale=font_scale_float)

df_marital_status_income.plot(x=feature_column_name_string, kind=plot_kind, stacked=True, title=title_string, mark_right=True, color=color_list, figsize=figure_size)

for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(df_marital_status_income.iloc[:, 1:].cumsum(1)[n], df_marital_status_income[n], df_rel[n])):
        plt.text(i, cs - ab / 2, str(np.round(pc, 1))+'%', va='center', ha='center', rotation=0, fontsize=14)
        
plt.ylabel('Frequency')

plt.tight_layout()

plt.savefig(fname=figure_filename, dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Relationship'

title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

plot_kind='bar'

color_list=['#fee8c8', '#addd8e']

figure_size=(8, 6)

font_scale_float=1.5


#DataFrame Calculation
df_relationship_income = df.groupby(['Relationship', 'Income']).size().unstack().reset_index()
df_relationship_income.loc[:, 'total']=df_relationship_income.loc[:, '≤50K']+df_relationship_income.loc[:, '>50K']
df_relationship_income.loc[:, '>50K_rate']=df_relationship_income.loc[:, '>50K']/df_relationship_income.loc[:, 'total']
df_relationship_income=df_relationship_income.sort_values(['>50K_rate', 'total'], ascending=False)
df_relationship_income=df_relationship_income.drop(columns=['total', '>50K_rate'])

df_total = df_relationship_income["≤50K"] + df_relationship_income[">50K"]
df_rel = df_relationship_income[df_relationship_income.columns[1:]].div(df_total, 0) * 100


#Create the Plot
sns.set(font_scale=font_scale_float)

df_relationship_income.plot(x=feature_column_name_string, kind=plot_kind, stacked=True, title=title_string, mark_right=True, color=color_list, figsize=figure_size)

for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(df_relationship_income.iloc[:, 1:].cumsum(1)[n], df_relationship_income[n], df_rel[n])):
        plt.text(i, cs-ab/2, str(np.round(pc, 1)) + '%', va = 'center', ha='center', rotation=0, fontsize=14)
        
plt.ylabel('Frequency')

plt.tight_layout()
plt.savefig(fname=figure_filename, dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Age'

title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

figure_size=(8,6)


#DataFrame Calculation
df_age_count=df.value_counts('Age').reset_index().rename(columns={0:'Frequency'})


#Create the Plot
plt.subplots(nrows=1, ncols=1, figsize=figure_size)
sns.scatterplot(x=feature_column_name_string, y='Frequency', data=df_age_count)
plt.suptitle(title_string, size = 20);

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Age'
target_column_name_value_list=['≤50K', '>50K']

title_string=feature_column_name_string.title()+' Per Income KDE Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

color_list=['b', '#BEB539']
figure_size=(8,6)


#Create the Plot
sns.set(style="darkgrid")

figure, axes=plt.subplots(nrows=1, ncols=1, figsize=figure_size)
axes=sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([target_column_name_value_list[0]]), :][feature_column_name_string], shade=False, color=color_list[0], label=target_column_name_value_list[0])
axes=sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([target_column_name_value_list[1]]), :][feature_column_name_string], shade=False, color=color_list[1], label=target_column_name_value_list[1])

plt.legend(frameon=False)
plt.suptitle(title_string, size=20);

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Age group'

title_string=feature_column_name_string.title()+' 2 Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

color_list=['tab:red', '#D9CC7A']
figure_size=(16, 8)

#DataFrame Calculation
df_age_bins_income=df.groupby(['Age group', 'Income']).size().reset_index().pivot(index='Age group', columns='Income', values=0).reset_index()
df_age_bins_income.loc[:, '>_≤_50K_ratio'] = df_age_bins_income.loc[:, '>50K'] / df_age_bins_income.loc[:, '≤50K']
df_age_bins_income.loc[:, 'total']=df_age_bins_income.loc[:, '>50K']+df_age_bins_income.loc[:, '≤50K']
df_age_bins_income.loc[:, 'Income >50K Percentage']=df_age_bins_income.loc[:, '>50K']/df_age_bins_income.loc[:, 'total']*100


#Create the Plot
sns.set_style("whitegrid", {'axes.grid' : False})
figure, axes=plt.subplots(nrows=1, ncols=1, figsize=figure_size)
#plt.figure(figsize=(8, 8))

bar1=sns.barplot(x=feature_column_name_string,  y='total', data=df_age_bins_income, color=color_list[0])
bar2=sns.barplot(x=feature_column_name_string, y='≤50K', data=df_age_bins_income, estimator=sum, ci=None,  color=color_list[1])
bar2.set_ylabel('Frequency', fontsize=16)

top_bar=mpatches.Patch(color=color_list[0], label='>50K')
bottom_bar=mpatches.Patch(color=color_list[1], label='≤50K')
plt.legend(handles=[top_bar, bottom_bar])


for patch, rate in zip(bar1.patches, df_age_bins_income.loc[:, 'Income >50K Percentage']):
    bar1.annotate(f'{rate:.0f}%', 
                   (patch.get_x() + patch.get_width() / 2., patch.get_height() + 833), 
                   ha = 'center', va = 'center', 
                   size=13,
                   xytext = (0, -12), 
                   textcoords = 'offset points')

bar1.set_ylim([0, 14000])

ax2 = bar1.twinx()
ax2.set_ylabel('Income >50K', fontsize=16)
ax2 = sns.lineplot(x='Age group', y='Income >50K Percentage', data = df_age_bins_income, sort=False, color=color_list[0])
ax2.tick_params(axis='y', color=color_list[0])

def percentage_formatter(x, pos):
    return f'{x:.0f}%'
ax2.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

plt.title(label=title_string)

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_list=['Age group', 'Education']

title_string=feature_column_name_list[0].title()+' Per '+feature_column_name_list[1].title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

line_plot_marker_size=10
palette_string='tab20'


#DataFrame Calculation
df_age_education_income=df.groupby(['Age group', 'Education'])['Income'].value_counts().unstack().reset_index()
df_age_education_income.loc[:, '>50K']=df_age_education_income.loc[:, '>50K'].fillna(0)
df_age_education_income.loc[:, 'total']=df_age_education_income.loc[:, '≤50K']+df_age_education_income.loc[:, '>50K']
df_age_education_income.loc[:, '>50K_rate']=df_age_education_income.loc[:, '>50K']/df_age_education_income.loc[:, 'total']
df_age_education_income.loc[:, '≤50K_rate']=df_age_education_income.loc[:, '≤50K']/df_age_education_income.loc[:, 'total']
df_education_educational_num = df.loc[:, ['Education', 'Educational number']].drop_duplicates().sort_values('Educational number')
df_age_education_income=pd.merge(df_age_education_income, df_education_educational_num, on='Education')
df_age_education_income=df_age_education_income.sort_values(['Age group', 'Educational number'])

#Create the Plot
figure, axes = plt.subplots(figsize=(15,6))
axes2 = axes.twinx()
g = sns.barplot(x=feature_column_name_list[0], y='total', hue=feature_column_name_list[1], data=df_age_education_income, ax=axes, palette=palette_string)
g = sns.lineplot(x=feature_column_name_list[0], y='>50K_rate', hue=feature_column_name_list[1], data=df_age_education_income, ax=axes2, marker='.', markersize=line_plot_marker_size, legend=None, palette=palette_string)


axes.set(ylabel='Frequency')
plt.tick_params(axis='x', rotation=45)
plt.xticks(ha="right")
plt.tick_params(bottom=False)
plt.tick_params(left=False)
plt.title(label=title_string)

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Education'
color_list=['r','#D9CC7A']

title_string=feature_column_name_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

font_scale_float=1.5
sns.set(font_scale=font_scale_float)


#DataFrame Calculation
df_education_income_greater_than_50k_income_less_than_or_equal_to_50k = df.groupby(['Education'])['Income'].value_counts().unstack().reset_index()
df_education_income_greater_than_50k_income_less_than_or_equal_to_50k.loc[:, 'Total']=df_education_income_greater_than_50k_income_less_than_or_equal_to_50k.loc[:, '≤50K'].values+df_education_income_greater_than_50k_income_less_than_or_equal_to_50k.loc[:, '>50K']
df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total=df_education_income_greater_than_50k_income_less_than_or_equal_to_50k.copy()
del df_education_income_greater_than_50k_income_less_than_or_equal_to_50k

df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total.loc[:, 'Income >50K Percentage']=df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total.loc[:, '>50K'].values/df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total.loc[:, 'Total']*100
df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total_income_greater_than_50k_percentage=df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total.copy()
del df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total
df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total_income_greater_than_50k_percentage=df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total_income_greater_than_50k_percentage.sort_values(['Income >50K Percentage', 'Total'], ascending=False)



#Create the Plot
figure, axes=plt.subplots(nrows=1, ncols=1, figsize=(8,6))
seaborn_plot=sns.barplot(x=feature_column_name_string,  y='Total', data=df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total_income_greater_than_50k_percentage, color=color_list[0])


bar2 = sns.barplot(x=feature_column_name_string, y='≤50K', data=df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total_income_greater_than_50k_percentage, color=color_list[1])

top_bar = mpatches.Patch(color=color_list[0], label='>50K')
bottom_bar = mpatches.Patch(color=color_list[1], label='≤50K')


for pp, rate in zip(seaborn_plot.patches, df_education_income_greater_than_50k_income_less_than_or_equal_to_50k_total_income_greater_than_50k_percentage.loc[:, 'Income >50K Percentage']):
    seaborn_plot.annotate(f'{rate:.0f}%', 
                   (patch.get_x() + patch.get_width() / 2., patch.get_height() + 833), 
                   ha = 'center', va = 'center', 
                   size=13,
                   xytext = (0, -12), 
                   textcoords = 'offset points')

plt.xlabel(feature_column_name_string, size=14)
plt.legend(handles=[top_bar, bottom_bar], frameon=False)
plt.tick_params(axis='x', rotation=90)
plt.ylabel('Frequency', size=14)
seaborn_plot.set_ylim(0,18000)
plt.suptitle(title_string, size=20);

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Capital gain'
title_string=feature_column_name_string.title()+' KDE Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

target_column_name_value_list=['≤50K', '>50K']
color_list=['#CBBD35', '#66B4BC']

font_scale_float=1.5


#Create the Plot
sns.set(font_scale=font_scale_float)
sns.set(style="darkgrid")

figure, axes=plt.subplots(nrows=1, ncols=1, figsize=(8,6))
axes = sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([target_column_name_value_list[0]]), :][feature_column_name_string], shade=False, color=color_list[0], label=target_column_name_value_list[0])
axes = sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([target_column_name_value_list[1]]), :][feature_column_name_string], shade=False, color=color_list[1], label=target_column_name_value_list[1])

plt.legend(frameon=False)
plt.title(label=title_string)


plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Hours per week'
target_column_name_value_list=['≤50K', '>50K']

color_list=['green', 'black']

title_string=feature_column_name_string.title()+' KDE Distribution'

figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

font_scale_float=1.5



#Create the Plot
sns.set(style="darkgrid")
sns.set(font_scale=font_scale_float)

figure, axes=plt.subplots(nrows=1, ncols=1, figsize=(8,6))
axes=sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([target_column_name_value_list[0]]), :][feature_column_name_string], shade=False, color=color_list[0], label=target_column_name_value_list[0])
axes=sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([target_column_name_value_list[1]]), :][feature_column_name_string], shade=False, color=color_list[1], label=target_column_name_value_list[1])

plt.legend(frameon=False)
plt.title(label=title_string)

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string_list=['Hours per week', 'Income >50K Percentage']

title_string=feature_column_name_string_list[0].title()+' Distribution and Income >50K Percentage'

figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'

color_list=['r', '#D9CC7A']



#calculation of DataFrames to plot
df_hours_per_week_greater_than_50k_less_or_equal_to_50k=df.groupby([feature_column_name_string_list[0],'Income']).size().unstack().reset_index().fillna(0)
df_hours_per_week_greater_than_50k_less_or_equal_to_50k.loc[:, 'Total']=df_hours_per_week_greater_than_50k_less_or_equal_to_50k.loc[:, '>50K']+df_hours_per_week_greater_than_50k_less_or_equal_to_50k.loc[:, '≤50K']
df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total = df_hours_per_week_greater_than_50k_less_or_equal_to_50k.copy()
del df_hours_per_week_greater_than_50k_less_or_equal_to_50k
df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total.loc[:, 'Income >50K Percentage']=df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total.loc[:, '>50K']/df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total.loc[:, 'Total']*100
df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total_income_greater_than_50k_percentage=df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total.copy()
del df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total
df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total_income_greater_than_50k_percentage

df_hours_per_week_income20=df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total_income_greater_than_50k_percentage.sort_values(['Total', 'Income >50K Percentage'], ascending=False).head(20).sort_values(feature_column_name_string_list[0])





#Create the Plot
figure, axes=plt.subplots(nrows=1, ncols=1, figsize=(17,8))
ax2 = axes.twinx()

splot = sns.barplot(x=feature_column_name_string, y='Total', data=df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total_income_greater_than_50k_percentage, color=color_list[0], ax=axes)

bar2 = sns.barplot(x=feature_column_name_string, y="≤50K", data=df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total_income_greater_than_50k_percentage, color=color_list[1], ax=axes)

axes.set(ylabel='Frequency')


top_bar = mpatches.Patch(color='r', label='>50K')
bottom_bar = mpatches.Patch(color='#D9CC7A', label='≤50K')


for pp, rate in zip(splot.patches, df_hours_per_week_greater_than_50k_less_or_equal_to_50k_total_income_greater_than_50k_percentage.loc[:, 'Income >50K Percentage']):

    if round(rate, 6) in round(df_hours_per_week_income20.loc[:, feature_column_name_string_list[1]], 6).values:
        splot.annotate(f'{rate:.0f}%', 
                       (patch.get_x() + patch.get_width() / 2., patch.get_height() + 1233), 
                       ha = 'center', va = 'center', 
                       size=11,
                       xytext = (0, -12), 
                       textcoords = 'offset points')

plt.xlabel(xlabel=feature_column_name_string, size=14)

axes.legend(handles=[top_bar, bottom_bar], frameon=False, loc=2)

plt.tick_params(axis='x', rotation=90)

plt.ylabel(ylabel='Frequency', size=14)

splot.set_ylim(0, 25000)

plt.suptitle(title_string, size=20);

df1=df_hours_per_week_income20.loc[:, [feature_column_name_string, 'Income >50K Percentage']]
df1.set_index(feature_column_name_string, inplace=True)


f1=interp1d(df1.index, df1.loc[:, 'Income >50K Percentage'], kind='cubic')


df2 = pd.DataFrame()
new_index = np.arange(df1.index.min(), df1.index.max())
df2.loc[:, 'Income >50K Percentage'] = f1(new_index)
df2.index = new_index - 1 

ax2 = df2.plot.line(ax=ax2)
ax2.set_xlabel(feature_column_name_string)
ax2.set_ylabel('Income >50K')

def percent_formatter(x, pos):
    return f'{x:.0f}%'
ax2.yaxis.set_major_formatter(plt.FuncFormatter(percent_formatter))


ax2.legend(frameon=False, loc=1)

axes.tick_params(axis='x', rotation=90)

sns.set_style(style='white')


plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)

plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Hours per week'

figure_filename='../reports/figures/figure_'+feature_column_name_string.replace(' ','_').lower()+'_violin_distribution_v'+filename_version+'.png'

title_string=feature_column_name_string.title()+' Violin Distribution'

font_scale_float=1.7


#Create the Plot
sns.set(font_scale=font_scale_float)

figure, axes=plt.subplots(figsize=(10,6))
sns.violinplot(x=feature_column_name_string, data=df)
plt.title(label=title_string)


plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
feature_column_name_string='Capital loss'

figure_filename='../reports/figures/figure_'+feature_column_name_string.replace(' ','_').lower()+'_kde_distribution_v'+filename_version+'.png'

title_string=feature_column_name_string.title()+' KDE Distribution'

color_list=['r', '#66B4BC']
label_list=['≤50K', '>50K']
bandwidth_method_float=.12
shade_boolean=False
frameon_boolean=False

font_scale_float=1.5


#Create the Plot
sns.set(style="darkgrid")
sns.set(font_scale=font_scale_float)

figure, axes=plt.subplots(figsize=(13,6))
sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([label_list[0]]), :][feature_column_name_string], shade=shade_boolean, color=color_list[0], label=label_list[0], bw_method=bandwidth_method_float)
sns.kdeplot(df.loc[df.loc[:, 'Income'].isin([label_list[1]]), :][feature_column_name_string], shade=shade_boolean, color=color_list[1], label=label_list[1], bw_method=bandwidth_method_float)

plt.title(label=title_string,)
plt.legend(frameon=frameon_boolean)

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()

# %%
#Intialize the Variables
figure_filename='../reports/figures/figure_feature_correlation_heatmap'+'_v'+filename_version+'.png'

title_string='Feature Correlation Heatmap'

feature_column_name_drop_list=['Final weight', 'Capital gain',  'Capital loss']

color_map_string='YlOrBr'
format_code_string='.2f'


figure_size=(10, 8)
font_scale_float=1.5
ytick_rotation=0


#DataFrame Calculation

#calculate the feature correlation DataFrame and feature correlation DataFrame reduced
df_feature_correlations=df.drop(columns=feature_column_name_drop_list).corr()
df_feature_correlations_reduced=df_feature_correlations.iloc[1:,:-1].copy()

#get feature correlation heatmap mask two dimensional array reduced
boolean_true_two_dimensional_array=np.ones_like(a=df_feature_correlations, dtype=np.bool)
feature_correlation_mask_two_dimensional_array_reduced=np.triu(m=boolean_true_two_dimensional_array, k=0)[1:, :-1]

del boolean_true_two_dimensional_array
del df_feature_correlations


#Create the Plot
sns.set(font_scale=font_scale_float)

figure, axes = plt.subplots(nrows=1, ncols=1, sharex=False, sharey=False, squeeze=True, figsize=figure_size)
sns.heatmap(data=df_feature_correlations_reduced, mask=feature_correlation_mask_two_dimensional_array_reduced, annot=True, fmt=format_code_string, cmap=color_map_string, vmin=-1, vmax=1, cbar_kws={"shrink": .8})

plt.yticks(rotation=ytick_rotation)
plt.title(label=title_string, fontdict={'fontsize': 22})

plt.savefig(fname=figure_filename, bbox_inches='tight', dpi=100)
plt.show()
# Out:
# /var/folders/77/y4hv4_s9751293nzv4yrfrtm0000gn/T/ipykernel_71091/3862260347.py:24: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   boolean_true_two_dimensional_array=np.ones_like(a=df_feature_correlations, dtype=np.bool)

# %%
#ioa.capital_loss_capital_gain_relationship_check(df)

# %% [markdown]
# <font size="5"><a id='[6.0_Modeling]'> </a> </font></font> <font>Table of Contents</font> <font size="2">[3.0 Data Wrangling](#[3.0_Data_Wrangling])</font> <font size="2">[4.0 Feature Engineering](#[4.0_Feature_Engineering])</font> <font size="2">[5.0 Exploratory Data Analysis](#[5.0_Exploratory_Data_Analysis])</font>  <font size="2">[6.0 Modeling](#[6.0_Modeling])</font> <font size="2">[7.0 Results](#[7.0_Results])</font>

# %% [markdown]
# <font size="5"><a id='[6.0_Modeling]'>**6.0 Modeling**</a> </font>

# %% [markdown]
# ### 6.1 Permutation Test<a id='6.1_Permutation_Testing'></a>

# %%
# stats.normaltest(df.loc[:, 'Age'])
# stats.normaltest(df.loc[:, 'Income ordinal integer encoding'])

# %%
#Income: ≤50K and >50K; Age: 17 thru 90

#Intialize the Variables
number_of_replicates=10000

feature_column_name_string='Age'
target_column_name_string='Income'

target_column_name_value_list=['≤50K', '>50K']

figure_size=(8,6)

xlabel_string='Absolute difference in mean '+feature_column_name_string.lower()+' between '+target_column_name_string.lower()+' groups'
ylabel_string='Frequency'

title_string=xlabel_string.title()+' Distribution'
figure_filename='../reports/figures/figure_'+title_string.replace(' ', '_').lower()+'_v'+filename_version+'.png'


#Absolute Difference of Feature and Target Group Mean Array Calculation
permuted_feature_column_name_and_target_column_name_group_mean_difference_absolute_value_array=np.empty(10000)
np.random.seed(200)
for i in range(number_of_replicates):
    df.loc[:, feature_column_name_string+' Permutation']=np.random.permutation(df.loc[:, feature_column_name_string])
    permuted_feature_column_name_and_target_column_name_group_mean_difference_absolute_value_array[i]=abs(df.loc[df.loc[:, target_column_name_string].isin([target_column_name_value_list[0]]), feature_column_name_string+' Permutation'].mean()-df.loc[df.loc[:, target_column_name_string].isin([target_column_name_value_list[1]]), feature_column_name_string+' Permutation'].mean())

observed_age_and_income_group_mean_difference_absolute_value=abs(df.loc[df.loc[:, 'Age']>40, 'Income ordinal integer encoding'].mean()-df.loc[df.loc[:, 'Age']<=40, 'Income ordinal integer encoding'].mean())

#Create the Plot
figure, axes=plt.subplots(nrows=1, ncols=1, figsize=figure_size)

plt.hist(permuted_feature_column_name_and_target_column_name_group_mean_difference_absolute_value_array, bins=44)
plt.axvline(x=observed_age_and_income_group_mean_difference_absolute_value, color='r', linestyle='--')

plt.title(label=title_string)
plt.xlabel(xlabel=xlabel_string)
plt.ylabel(ylabel=ylabel_string)

plt.legend(labels=['Observed Mean Absolute Difference', 'Simulated Mean Absolute Difference'], loc='upper right')

#plt.tight_layout()



plt.savefig(fname=figure_filename, bbox_inches='tight',dpi=100)
plt.show()

# %%
df=df.drop(columns='Age Permutation')

# %% [markdown]
# <font size="5"><a id='[7.0_Results]'></a> </font> </font> <font>Table of Contents</font> <font size="2">[3.0 Data Wrangling](#[3.0_Data_Wrangling])</font> <font size="2">[4.0 Feature Engineering](#[4.0_Feature_Engineering])</font> <font size="2">[5.0 Exploratory Data Analysis](#[5.0_Exploratory_Data_Analysis])</font>  <font size="2">[6.0 Modeling](#[6.0_Modeling])</font> <font size="2">[7.0 Results](#[7.0_Results])</font>

# %% [markdown]
# <font size="5"><a id='[7.0_Results]'>**7.0 Results**</a> </font>

# %%
#Calculation of p-value
observed_age_and_income_group_mean_difference_absolute_value_simulated_difference_absolute_value_percentage_greater=np.sum(permuted_feature_column_name_and_target_column_name_group_mean_difference_absolute_value_array>observed_age_and_income_group_mean_difference_absolute_value)/len(permuted_feature_column_name_and_target_column_name_group_mean_difference_absolute_value_array)*100


'The number of absolute differences greater than the observed absolute difference is '+\
str(observed_age_and_income_group_mean_difference_absolute_value_simulated_difference_absolute_value_percentage_greater)+\
'% (i.e. >5%) and therefore we reject the null hypothesis.'
# Out:
# 'The number of absolute differences greater than the observed absolute difference is 18.92% (i.e. >5%) and therefore we reject the null hypothesis.'
